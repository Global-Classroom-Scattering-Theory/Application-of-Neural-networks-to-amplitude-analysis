# %% [markdown]
# # <font color="yellow"> Loading the data for training and prediction </font>

# %%
# !git clone https://github.com/Global-Classroom-Scattering-Theory/Application-of-Neural-networks-to-amplitude-analysis.git ./ANNProject
# Out:
# Cloning into './ANNProject'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 41 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (41/41), done.
# Checking out files: 100% (30/30), done.

# %%
import os
path=os.path.expanduser("./ANNProject/dataset/")

# %%
import glob
import pandas as pd
import os

dfs =[]

for filename in sorted(glob.glob(path+"ln*.csv")):

    print(filename)
    dfs.append(pd.read_csv(filename,sep=";"))    

    
data=pd.concat(dfs)
# Out:
# ./ANNProject/dataset/ln200k65bins_part_01.csv
# ./ANNProject/dataset/ln200k65bins_part_02.csv
# ./ANNProject/dataset/ln200k65bins_part_03.csv
# ./ANNProject/dataset/ln200k65bins_part_04.csv
# ./ANNProject/dataset/ln200k65bins_part_05.csv
# ./ANNProject/dataset/ln200k65bins_part_06.csv
# ./ANNProject/dataset/ln200k65bins_part_07.csv
# ./ANNProject/dataset/ln200k65bins_part_08.csv
# ./ANNProject/dataset/ln200k65bins_part_09.csv
# ./ANNProject/dataset/ln200k65bins_part_10.csv
# ./ANNProject/dataset/ln200k65bins_part_11.csv
# ./ANNProject/dataset/ln200k65bins_part_12.csv
# ./ANNProject/dataset/ln200k65bins_part_13.csv
# ./ANNProject/dataset/ln200k65bins_part_14.csv
# ./ANNProject/dataset/ln200k65bins_part_15.csv
# ./ANNProject/dataset/ln200k65bins_part_16.csv
# ./ANNProject/dataset/ln200k65bins_part_17.csv
# ./ANNProject/dataset/ln200k65bins_part_18.csv
# ./ANNProject/dataset/ln200k65bins_part_19.csv
# ./ANNProject/dataset/ln200k65bins_part_20.csv
# ./ANNProject/dataset/ln200k65bins_part_21.csv
# ./ANNProject/dataset/ln200k65bins_part_22.csv
# ./ANNProject/dataset/ln200k65bins_part_23.csv
# ./ANNProject/dataset/ln200k65bins_part_24.csv
# ./ANNProject/dataset/ln200k65bins_part_25.csv

# %%
data.shape
# Out:
# (200000, 151)

# %% [markdown]
# # <font color="yellow"> Extractig columns containing the signal and background intensities</font>

# %%
import numpy as np

fulldataset = data

lowe=4.251 #4.101 #4.251
upe=4.379 #4.399 #4.379
widthe=0.002

longCols=["M22Sign","RS1","RS2","RS3","RS4",]
floatCols=[col for col in fulldataset.columns if col not in longCols]
fulldataset[longCols]=fulldataset[longCols].astype("long")
fulldataset[floatCols]=fulldataset[floatCols].astype("float32")
fulldataset=fulldataset[(fulldataset.RS3==4) | (fulldataset.RS3==2)]

hyperparam_cols=["p0","p1","b0","b1","M11","M22","M12SQ","M22Sign"
                 ,"Re1","Im1","RS1","Re2","Im2","RS2","Re3","Im3","RS3","Re4","Im4","RS4"]
hyperparams=fulldataset[hyperparam_cols]


x_cols=[col for col in fulldataset.columns if col not in hyperparam_cols]
e=[energy for energy in x_cols if energy[:4]=="_sig"]
e=[float(energy.split("_")[2]) for energy in e]
e=np.array([energy for energy in e if energy<=upe and energy>=lowe])
# sig_energies=["sig_"+str(energy) for energy in e]
# bkg_energies=["bkg_"+str(energy) for energy in e]
sig_c_energies=["_sig_"+str(energy) for energy in e]
bkg_c_energies=["_bkg_"+str(energy) for energy in e]

X_c=fulldataset[sig_c_energies].values+fulldataset[bkg_c_energies].values # energy resolved
# X_p=fulldataset[sig_energies].values+fulldataset[bkg_energies].values # perfect resolution
Y=np.ravel(fulldataset["classes"])

# %% [markdown]
# # <font color="yellow"> Adding Gaussian noise to the signal</font>

# %%
#  noise 
import numpy as np
import pandas as pd

mu, sigma = 0, 1 # mean and standard deviation
noiseStd = 0.05

dataX_sig = fulldataset[sig_c_energies].values
dataX_bkg = fulldataset[bkg_c_energies].values
noise = np.zeros(dataX_sig.shape)
print(dataX_sig.shape)
for i in range(dataX_sig.shape[0]):
    noise[i] = np.random.normal(mu, sigma, size=(65)) * dataX_sig[i, :].max() * noiseStd

X_noise = dataX_sig + noise
X_completed=X_noise+fulldataset[bkg_c_energies].values # energy resolved


# X = X_c
print(X_c.shape, X_completed.shape, Y.shape)
# Out:
# (200000, 65)
# (200000, 65) (200000, 65) (200000,)

# %% [markdown]
# # <font color="yellow"> Scaling the training data to the [0,1] interval.
# Note: usually one scales columnwise, as it is assumed that features are independent and identically distributed. Here this is not the case - adjacent data form the curve.</font>

# %%
from sklearn.preprocessing import minmax_scale

X_scaled = minmax_scale(X_completed, axis=1)

# %% [markdown]
# # <font color="yellow"> One-hot encoding</font>

# %%
from tensorflow.keras.utils import to_categorical

Yenc=to_categorical(Y)

# %% [markdown]
# # <font color="yellow">Train-test split</font>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Yenc, test_size=0.3,random_state=1)

# %%
X_train.shape
# Out:
# (140000, 65)

# %% [markdown]
# # <font color="yellow">Model construction</font>

# %%
# Import `Sequential` from `keras.models`
from tensorflow.keras.models import Sequential

# Import `Dense` from `keras.layers`
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

def makeModel(dropout=False):
# Initialize the constructor
    model = Sequential()

# Add an input layer 
    model.add(Dense(400, activation='relu', input_shape=(65,)))
    if dropout:
        model.add(Dropout(.2))
# Add one hidden layer 
    model.add(Dense(200, activation='relu'))
    if dropout:
        model.add(Dropout(.5))
# # Add one hidden layer 
#     model.add(Dense(200, activation='relu'))
#     if dropout:
#         model.add(Dropout(.2))

# Add an output layer 
    model.add(Dense(4, activation='softmax'))
    return model

model=makeModel()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 400)               26400
#
#  dense_1 (Dense)             (None, 200)               80200
#
#  dense_2 (Dense)             (None, 4)                 804
#
# =================================================================
# Total params: 107,404
# Trainable params: 107,404
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # <font color="yellow">Model training</font>

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
                   
history=model.fit(X_train, Y_train,epochs=100,batch_size=1024, validation_split=.25, verbose=1)

try:
  import cPickle as pickle
except:
  import pickle

pickle.dump(history.history,open("MLP-LN_DS.pck","wb"))

model.save("MLP-LN_DS.mod")
# Out:
# Epoch 1/100
# 103/103 [==============================] - 3s 22ms/step - loss: 0.5337 - accuracy: 0.7930 - val_loss: 0.3268 - val_accuracy: 0.8765
# Epoch 2/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.2951 - accuracy: 0.8895 - val_loss: 0.2727 - val_accuracy: 0.8989
# Epoch 3/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.2624 - accuracy: 0.9002 - val_loss: 0.2530 - val_accuracy: 0.9015
# Epoch 4/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.2424 - accuracy: 0.9066 - val_loss: 0.2364 - val_accuracy: 0.9089
# Epoch 5/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.2317 - accuracy: 0.9097 - val_loss: 0.2291 - val_accuracy: 0.9106
# Epoch 6/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.2229 - accuracy: 0.9122 - val_loss: 0.2461 - val_accuracy: 0.9003
# Epoch 7/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.2167 - accuracy: 0.9142 - val_loss: 0.2144 - val_accuracy: 0.9163
# Epoch 8/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.2108 - accuracy: 0.9168 - val_loss: 0.2107 - val_accuracy: 0.9172
# Epoch 9/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.2069 - accuracy: 0.9180 - val_loss: 0.2088 - val_accuracy: 0.9176
# Epoch 10/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.2025 - accuracy: 0.9199 - val_loss: 0.2022 - val_accuracy: 0.9191
# Epoch 11/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1980 - accuracy: 0.9215 - val_loss: 0.2019 - val_accuracy: 0.9179
# Epoch 12/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1986 - accuracy: 0.9213 - val_loss: 0.2039 - val_accuracy: 0.9187
# Epoch 13/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.1959 - accuracy: 0.9218 - val_loss: 0.1950 - val_accuracy: 0.9220
# Epoch 14/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.1932 - accuracy: 0.9227 - val_loss: 0.2127 - val_accuracy: 0.9133
# Epoch 15/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.1945 - accuracy: 0.9221 - val_loss: 0.1974 - val_accuracy: 0.9217
# Epoch 16/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.1908 - accuracy: 0.9239 - val_loss: 0.1901 - val_accuracy: 0.9242
# Epoch 17/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1898 - accuracy: 0.9240 - val_loss: 0.2004 - val_accuracy: 0.9178
# Epoch 18/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1869 - accuracy: 0.9255 - val_loss: 0.1975 - val_accuracy: 0.9193
# Epoch 19/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.1874 - accuracy: 0.9254 - val_loss: 0.1869 - val_accuracy: 0.9237
# Epoch 20/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.1833 - accuracy: 0.9269 - val_loss: 0.1898 - val_accuracy: 0.9228
# Epoch 21/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1817 - accuracy: 0.9275 - val_loss: 0.1937 - val_accuracy: 0.9221
# Epoch 22/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1834 - accuracy: 0.9270 - val_loss: 0.1902 - val_accuracy: 0.9214
# Epoch 23/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1841 - accuracy: 0.9261 - val_loss: 0.1837 - val_accuracy: 0.9246
# Epoch 24/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.1792 - accuracy: 0.9282 - val_loss: 0.1849 - val_accuracy: 0.9247
# Epoch 25/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1789 - accuracy: 0.9280 - val_loss: 0.1925 - val_accuracy: 0.9218
# Epoch 26/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1776 - accuracy: 0.9288 - val_loss: 0.1895 - val_accuracy: 0.9239
# Epoch 27/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1806 - accuracy: 0.9275 - val_loss: 0.1935 - val_accuracy: 0.9193
# Epoch 28/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1784 - accuracy: 0.9282 - val_loss: 0.1830 - val_accuracy: 0.9259
# Epoch 29/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1766 - accuracy: 0.9291 - val_loss: 0.1928 - val_accuracy: 0.9223
# Epoch 30/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1784 - accuracy: 0.9286 - val_loss: 0.1892 - val_accuracy: 0.9226
# Epoch 31/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.1771 - accuracy: 0.9286 - val_loss: 0.1875 - val_accuracy: 0.9236
# Epoch 32/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1758 - accuracy: 0.9295 - val_loss: 0.1877 - val_accuracy: 0.9231
# Epoch 33/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.1738 - accuracy: 0.9296 - val_loss: 0.1954 - val_accuracy: 0.9180
# Epoch 34/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1738 - accuracy: 0.9304 - val_loss: 0.1843 - val_accuracy: 0.9250
# Epoch 35/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1742 - accuracy: 0.9298 - val_loss: 0.1823 - val_accuracy: 0.9261
# Epoch 36/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1712 - accuracy: 0.9309 - val_loss: 0.1886 - val_accuracy: 0.9233
# Epoch 37/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1740 - accuracy: 0.9301 - val_loss: 0.1803 - val_accuracy: 0.9265
# Epoch 38/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1693 - accuracy: 0.9319 - val_loss: 0.1800 - val_accuracy: 0.9268
# Epoch 39/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1719 - accuracy: 0.9307 - val_loss: 0.1841 - val_accuracy: 0.9257
# Epoch 40/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.1711 - accuracy: 0.9314 - val_loss: 0.1875 - val_accuracy: 0.9245
# Epoch 41/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.1705 - accuracy: 0.9316 - val_loss: 0.1848 - val_accuracy: 0.9235
# Epoch 42/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1689 - accuracy: 0.9318 - val_loss: 0.1798 - val_accuracy: 0.9269
# Epoch 43/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1698 - accuracy: 0.9307 - val_loss: 0.1946 - val_accuracy: 0.9239
# Epoch 44/100
# 103/103 [==============================] - 2s 20ms/step - loss: 0.1686 - accuracy: 0.9317 - val_loss: 0.1808 - val_accuracy: 0.9248
# Epoch 45/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1668 - accuracy: 0.9327 - val_loss: 0.1882 - val_accuracy: 0.9230
# Epoch 46/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1667 - accuracy: 0.9325 - val_loss: 0.1875 - val_accuracy: 0.9222
# Epoch 47/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1673 - accuracy: 0.9324 - val_loss: 0.1786 - val_accuracy: 0.9273
# Epoch 48/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1666 - accuracy: 0.9324 - val_loss: 0.1936 - val_accuracy: 0.9218
# Epoch 49/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1676 - accuracy: 0.9325 - val_loss: 0.1859 - val_accuracy: 0.9261
# Epoch 50/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1645 - accuracy: 0.9335 - val_loss: 0.1799 - val_accuracy: 0.9267
# Epoch 51/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1633 - accuracy: 0.9342 - val_loss: 0.1841 - val_accuracy: 0.9249
# Epoch 52/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1684 - accuracy: 0.9320 - val_loss: 0.1779 - val_accuracy: 0.9271
# Epoch 53/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1620 - accuracy: 0.9348 - val_loss: 0.1910 - val_accuracy: 0.9241
# Epoch 54/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1648 - accuracy: 0.9328 - val_loss: 0.1785 - val_accuracy: 0.9271
# Epoch 55/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1638 - accuracy: 0.9340 - val_loss: 0.1772 - val_accuracy: 0.9274
# Epoch 56/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1635 - accuracy: 0.9343 - val_loss: 0.1828 - val_accuracy: 0.9248
# Epoch 57/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1619 - accuracy: 0.9350 - val_loss: 0.1778 - val_accuracy: 0.9258
# Epoch 58/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1614 - accuracy: 0.9346 - val_loss: 0.1804 - val_accuracy: 0.9268
# Epoch 59/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1623 - accuracy: 0.9343 - val_loss: 0.1875 - val_accuracy: 0.9229
# Epoch 60/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1614 - accuracy: 0.9351 - val_loss: 0.1800 - val_accuracy: 0.9260
# Epoch 61/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1609 - accuracy: 0.9352 - val_loss: 0.1789 - val_accuracy: 0.9273
# Epoch 62/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1604 - accuracy: 0.9352 - val_loss: 0.1816 - val_accuracy: 0.9255
# Epoch 63/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1616 - accuracy: 0.9344 - val_loss: 0.1777 - val_accuracy: 0.9276
# Epoch 64/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1614 - accuracy: 0.9351 - val_loss: 0.1774 - val_accuracy: 0.9257
# Epoch 65/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1586 - accuracy: 0.9352 - val_loss: 0.1782 - val_accuracy: 0.9289
# Epoch 66/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1576 - accuracy: 0.9365 - val_loss: 0.1791 - val_accuracy: 0.9266
# Epoch 67/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1569 - accuracy: 0.9365 - val_loss: 0.1814 - val_accuracy: 0.9264
# Epoch 68/100
# 103/103 [==============================] - 2s 22ms/step - loss: 0.1580 - accuracy: 0.9367 - val_loss: 0.1956 - val_accuracy: 0.9180
# Epoch 69/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1587 - accuracy: 0.9361 - val_loss: 0.1819 - val_accuracy: 0.9269
# Epoch 70/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1566 - accuracy: 0.9371 - val_loss: 0.1779 - val_accuracy: 0.9271
# Epoch 71/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1560 - accuracy: 0.9373 - val_loss: 0.1801 - val_accuracy: 0.9263
# Epoch 72/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1544 - accuracy: 0.9373 - val_loss: 0.1786 - val_accuracy: 0.9255
# Epoch 73/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1556 - accuracy: 0.9370 - val_loss: 0.1756 - val_accuracy: 0.9291
# Epoch 74/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1556 - accuracy: 0.9366 - val_loss: 0.1800 - val_accuracy: 0.9258
# Epoch 75/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1560 - accuracy: 0.9369 - val_loss: 0.1855 - val_accuracy: 0.9243
# Epoch 76/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1545 - accuracy: 0.9373 - val_loss: 0.1749 - val_accuracy: 0.9280
# Epoch 77/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1549 - accuracy: 0.9373 - val_loss: 0.1815 - val_accuracy: 0.9270
# Epoch 78/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1561 - accuracy: 0.9366 - val_loss: 0.1793 - val_accuracy: 0.9274
# Epoch 79/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1531 - accuracy: 0.9380 - val_loss: 0.1765 - val_accuracy: 0.9281
# Epoch 80/100
# 103/103 [==============================] - 2s 24ms/step - loss: 0.1545 - accuracy: 0.9377 - val_loss: 0.1816 - val_accuracy: 0.9277
# Epoch 81/100
# 103/103 [==============================] - 3s 24ms/step - loss: 0.1516 - accuracy: 0.9388 - val_loss: 0.1785 - val_accuracy: 0.9280
# Epoch 82/100
# 103/103 [==============================] - 3s 33ms/step - loss: 0.1547 - accuracy: 0.9378 - val_loss: 0.1817 - val_accuracy: 0.9246
# Epoch 83/100
# 103/103 [==============================] - 2s 22ms/step - loss: 0.1542 - accuracy: 0.9372 - val_loss: 0.1803 - val_accuracy: 0.9250
# Epoch 84/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1540 - accuracy: 0.9375 - val_loss: 0.1787 - val_accuracy: 0.9282
# Epoch 85/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1509 - accuracy: 0.9394 - val_loss: 0.1744 - val_accuracy: 0.9278
# Epoch 86/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1521 - accuracy: 0.9382 - val_loss: 0.1760 - val_accuracy: 0.9291
# Epoch 87/100
# 103/103 [==============================] - 2s 22ms/step - loss: 0.1523 - accuracy: 0.9378 - val_loss: 0.1755 - val_accuracy: 0.9285
# Epoch 88/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1516 - accuracy: 0.9383 - val_loss: 0.1827 - val_accuracy: 0.9251
# Epoch 89/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1509 - accuracy: 0.9389 - val_loss: 0.1938 - val_accuracy: 0.9232
# Epoch 90/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1512 - accuracy: 0.9385 - val_loss: 0.1775 - val_accuracy: 0.9277
# Epoch 91/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1508 - accuracy: 0.9389 - val_loss: 0.1758 - val_accuracy: 0.9292
# Epoch 92/100
# 103/103 [==============================] - 2s 22ms/step - loss: 0.1481 - accuracy: 0.9396 - val_loss: 0.1763 - val_accuracy: 0.9304
# Epoch 93/100
# 103/103 [==============================] - 2s 22ms/step - loss: 0.1500 - accuracy: 0.9391 - val_loss: 0.1792 - val_accuracy: 0.9270
# Epoch 94/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1495 - accuracy: 0.9395 - val_loss: 0.1893 - val_accuracy: 0.9246
# Epoch 95/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1487 - accuracy: 0.9399 - val_loss: 0.1783 - val_accuracy: 0.9282
# Epoch 96/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1484 - accuracy: 0.9398 - val_loss: 0.1763 - val_accuracy: 0.9306
# Epoch 97/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1490 - accuracy: 0.9399 - val_loss: 0.1772 - val_accuracy: 0.9295
# Epoch 98/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1504 - accuracy: 0.9389 - val_loss: 0.1768 - val_accuracy: 0.9285
# Epoch 99/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1462 - accuracy: 0.9408 - val_loss: 0.1801 - val_accuracy: 0.9279
# Epoch 100/100
# 103/103 [==============================] - 2s 21ms/step - loss: 0.1464 - accuracy: 0.9411 - val_loss: 0.1775 - val_accuracy: 0.9285
# INFO:tensorflow:Assets written to: MLP-LN_DS.mod/assets

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
import tensorflow.keras as kr

try:
  import cPickle as pickle
except:
  import pickle

pickled_hist=pickle.load(open("MLP-LN_DS.pck","rb")) 


loaded_model=kr.models.load_model("MLP-LN_DS.mod")

model=loaded_model
# summarize history for accuracy
plt.plot(pickled_hist['accuracy'])
plt.plot(pickled_hist['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(pickled_hist['loss'])
plt.plot(pickled_hist['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # <font color="yellow">Loading data for prediction</font>

# %%
import pandas as pd
weight_ds=pd.read_csv(path+"boot_weight.csv",sep=";")
all_ds=pd.read_csv(path+"boot_all.csv",sep=";")
kp_ds=pd.read_csv(path+"boot_kp.csv",sep=";")

# %% [markdown]
# # <font color="yellow">Prediction</font>

# %%
from sklearn.preprocessing import minmax_scale

y_pred_weight=model.predict(minmax_scale(weight_ds, axis=1))

y_pred_all=model.predict(minmax_scale(all_ds, axis=1))

y_pred_kp=model.predict(minmax_scale(kp_ds, axis=1))

# %%
lab_weight=y_pred_weight.argmax(axis=1)
lab_all=y_pred_all.argmax(axis=1)
lab_kp=y_pred_kp.argmax(axis=1)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.hist(lab_weight)
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.hist(lab_all)
plt.show()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.hist(lab_kp)
plt.show()

# %%
from matplotlib import pyplot as plt 
import numpy as np  

# ########################################################################### 
# probability distributions of predictions for different experimental dataset
# ###########################################################################

idx = 1
series = ['boot_weight', 'boot_kp', 'boot_all']
bins = 100
colors = ['r', 'g', 'b', 'y']
classes = ['b | 2','b | 4','v | 2','v | 4']
plt.figure(figsize=(20,4))
for f in [y_pred_weight, y_pred_kp, y_pred_all]:
  # plt.figure(figsize=(20,4))
  plt.subplot(1,3,idx)

  ymax = 1500
  ax = plt.gca()
  # ax.set_xlim([xmin, xmax])
  ax.set_ylim([None, ymax])

  for i in [0,1,2,3]:   
    plt.hist(f[:,i], bins = bins, color=colors[i]) 
    plt.title(series[idx-1] + " :: PDF :: " + str(bins) + " bins") 
    plt.legend(classes)
  idx += 1
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
